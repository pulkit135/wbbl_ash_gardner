# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)
pd.set_option('display.expand_frame_repr',False)
pd.set_option ('max_colwidth',-1)

# %%
df=pd.read_csv('wbbl_all_data.csv')

# %%
df
# Out:
#        match_id   season  start_date                      venue  innings  ball   batting_team       bowling_team    striker non_striker        bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 0      1188382   2019/20  18-10-2019  North Sydney Oval          1        0.1   Sydney Sixers  Sydney Thunder     EA Perry   AJ Healy    S Ismail      4             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 1      1188382   2019/20  18-10-2019  North Sydney Oval          1        0.2   Sydney Sixers  Sydney Thunder     EA Perry   AJ Healy    S Ismail      2             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# ...

# %%
df['season'].unique()
# Out:
# array(['2019/20', '2018/19', '2017/18', '2016/17', '2015/16', '2020/21',
#        '2021/22', '2022/23'], dtype=object)

# %%
df_latest=df[df['season']=='2022/23']

# %%
df_latest
# Out:
#        match_id   season  start_date                                   venue  innings  ball   batting_team       bowling_team     striker non_striker        bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 73582  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  1        0.1   Brisbane Heat  Sydney Sixers      GM Harris   G Redmayne  L Cheatle     0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 73583  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  1        0.2   Brisbane Heat  Sydney Sixers      GM Harris   G Redmayne  L Cheatle     0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# ...

# %%
top_batters=pd.DataFrame(df_latest.groupby(['striker'])['runs_off_bat'].sum().sort_values(ascending=False))

# %%
df_latest.groupby(['striker'])['ball'].count().sort_values(ascending=False)
# Out:
# striker
# L Wolvaardt       386
# BL Mooney         368
# EA Perry          356
# G Redmayne        342
# KM Mack           340
#                  ...
# HL Ferling        4
# CG Sippel         4
# U Raymond-Hoey    3
# M Hinkley         2
# L Cheatle         1
# Name: ball, Length: 103, dtype: int64

# %%
top_batters=top_batters.merge(pd.DataFrame(df_latest.groupby(['striker'])['ball'].count().sort_values(ascending=False)),on='striker')

# %%
top_batters['strike_rate']=100*(top_batters['runs_off_bat']/top_batters['ball'])

# %%
top_batters
# Out:
#                 runs_off_bat  ball  strike_rate
# striker
# BL Mooney       434           368   117.934783
# EA Perry        408           356   114.606742
# L Wolvaardt     403           386   104.404145
# M du Preez      380           321   118.380062
# DJS Dottin      362           330   109.696970
# ...             ...           ...          ...
# D Brown         3             5     60.000000
# PA Bowdler      2             4     50.000000
# M Hinkley       1             2     50.000000
# L Cheatle       1             1     100.000000
# U Raymond-Hoey  0             3     0.000000
#
# [103 rows x 3 columns]

# %%
top_batters.sort_values(by='strike_rate',ascending=False,inplace=True)

# %%
top_batters=top_batters[top_batters['runs_off_bat']>=50]

# %%
top_batters.head(50)
#Ash Gardner at #6
# Out:
#                runs_off_bat  ball  strike_rate
# striker
# L Harris       270           136   198.529412
# A King         68            40    170.000000
# T Flintoff     116           72    161.111111
# S Ecclestone   126           81    155.555556
# M Brown        105           69    152.173913
# A Gardner      339           229   148.034934
# EA Burns       295           206   143.203883
# M Kapp         229           165   138.787879
# JL Jonassen    148           114   129.824561
# A Capsey       259           206   125.728155
# DN Wyatt       263           211   124.644550
# AJ Healy       330           268   123.134328
# R Johnston     103           86    119.767442
# H Graham       258           216   119.444444
# M du Preez     380           321   118.380062
# BL Mooney      434           368   117.934783
# P Cleary       53            45    117.777778
# E Kershaw      100           85    117.647059
# NE Stalenberg  59            51    115.686275
# ...

# %%
average_sr=100*(df_latest['runs_off_bat'].sum()/df_latest['ball'].count())
average_sr
#average strike rate for 2022/23 season of the WBBL
# Out:
# 108.73307770561075

# %%
top_batters.reset_index(inplace=True)

# %%
top_batters
# Out:
#          striker  runs_off_bat  ball  strike_rate
# 0   L Harris      270           136   198.529412
# 1   A King        68            40    170.000000
# 2   T Flintoff    116           72    161.111111
# 3   S Ecclestone  126           81    155.555556
# 4   M Brown       105           69    152.173913
# ..      ...       ...           ..           ...
# 59  AC Jayangani  133           156   85.256410
# 60  R Trenaman    131           156   83.974359
# 61  KJ Garth      115           141   81.560284
# 62  M Carmichael  69            90    76.666667
# 63  T Wilson      85            115   73.913043
#
# [64 rows x 4 columns]

# %%
gardner=df_latest[df_latest['striker']=='A Gardner']

# %%
#gardner.groupby(['match_id'])['runs_off_bat'].sum(),gardner.groupby(['match_id'])['ball'].count()

# %%
gardner
# Out:
#        match_id   season  start_date                                   venue  innings  ball   batting_team       bowling_team    striker non_striker        bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 73731  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  2        3.7   Sydney Sixers  Brisbane Heat      A Gardner  EA Perry    NM Hancock    2             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 73735  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  2        4.4   Sydney Sixers  Brisbane Heat      A Gardner  EA Perry    JM Kerr       0             0      NaN    NaN      NaN   NaN      NaN       stumped     A Gardner       NaN                NaN
# ...

# %%
len(gardner)
#balls faced by Ash Gardner in WBBL 2022/23
# Out:
# 229

# %%
gardner_death=gardner[gardner['ball']>10]

# %%
gardner_death
# Out:
#        match_id   season  start_date                             venue  innings  ball   batting_team       bowling_team    striker non_striker      bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 74200  1323556   2022/23  15-10-2022  Great Barrier Reef Arena, Mackay  1        19.6  Sydney Sixers  Adelaide Strikers  A Gardner  SW Bates    ML Schutt   6             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 74636  1323559   2022/23  16-10-2022  Great Barrier Reef Arena, Mackay  1        10.3  Sydney Sixers  Melbourne Stars    A Gardner  EA Perry    A Capsey    0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# ...

# %%
len(gardner_death)
# Out:
# 101

# %%
gardner_death['runs_off_bat'].sum()
# Out:
# 180

# %%
gardner_death['match_id'].unique()
# Out:
# array([1323556, 1323559, 1323577, 1323580, 1323595, 1323604, 1323607],
#       dtype=int64)

# %%
gardner['match_id'].unique()

#In 7/14 Ash Gardner stayed beyond the 10th over
# Out:
# array([1323554, 1323556, 1323559, 1323566, 1323574, 1323577, 1323580,
#        1323584, 1323593, 1323595, 1323602, 1323604, 1323607, 1341268],
#       dtype=int64)

# %%
gardner_matches=[1323554, 1323556, 1323559, 1323566, 1323574, 1323577, 1323580,
       1323584, 1323593, 1323595, 1323602, 1323604, 1323607, 1341268]

# %%
gardner
# Out:
#        match_id   season  start_date                                   venue  innings  ball   batting_team       bowling_team    striker non_striker        bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 73731  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  2        3.7   Sydney Sixers  Brisbane Heat      A Gardner  EA Perry    NM Hancock    2             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 73735  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  2        4.4   Sydney Sixers  Brisbane Heat      A Gardner  EA Perry    JM Kerr       0             0      NaN    NaN      NaN   NaN      NaN       stumped     A Gardner       NaN                NaN
# ...

# %%
gardner.reset_index()
# Out:
#      index  match_id   season  start_date                                   venue  innings  ball   batting_team       bowling_team    striker non_striker        bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 0    73731  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  2        3.7   Sydney Sixers  Brisbane Heat      A Gardner  EA Perry    NM Hancock    2             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 1    73735  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  2        4.4   Sydney Sixers  Brisbane Heat      A Gardner  EA Perry    JM Kerr       0             0      NaN    NaN      NaN   NaN      NaN       stumped     A Gardner       NaN                NaN
# ...

# %%
gardner_entry=pd.DataFrame(gardner.groupby(['match_id'])['ball'].min())
gardner_exit=pd.DataFrame(gardner.groupby(['match_id'])['ball'].max())

# %%
gardner_entry
# Out:
#           ball
# match_id
# 1323554   3.7
# 1323556   19.6
# 1323559   9.4
# 1323566   4.2
# 1323574   1.4
# 1323577   16.5
# 1323580   1.6
# 1323584   7.2
# 1323593   5.2
# 1323595   18.3
# 1323602   3.5
# 1323604   3.2
# 1323607   9.3
# 1341268   4.3

# %%
gardner_exit
# Out:
#           ball
# match_id
# 1323554   4.4
# 1323556   19.6
# 1323559   17.6
# 1323566   7.5
# 1323574   6.5
# 1323577   19.5
# 1323580   13.2
# 1323584   7.3
# 1323593   9.2
# 1323595   19.3
# 1323602   8.3
# 1323604   19.2
# 1323607   18.5
# 1341268   4.6

# %%
gardner_perf=gardner_entry.merge(gardner_exit,on='match_id')

# %%
gardner_perf.rename(columns={'ball_x':'entry','ball_y':'exit'},inplace=True)

# %%
gardner_perf
# Out:
#           entry  exit
# match_id
# 1323554   3.7    4.4
# 1323556   19.6   19.6
# 1323559   9.4    17.6
# 1323566   4.2    7.5
# 1323574   1.4    6.5
# 1323577   16.5   19.5
# 1323580   1.6    13.2
# 1323584   7.2    7.3
# 1323593   5.2    9.2
# 1323595   18.3   19.3
# 1323602   3.5    8.3
# 1323604   3.2    19.2
# 1323607   9.3    18.5
# 1341268   4.3    4.6

# %%
gardner_perf=gardner_perf.merge(pd.DataFrame(gardner.groupby(['match_id'])['runs_off_bat'].sum()),on='match_id')

# %%
gardner_perf
# Out:
#           entry  exit  runs_off_bat
# match_id
# 1323554   3.7    4.4   2
# 1323556   19.6   19.6  6
# 1323559   9.4    17.6  24
# 1323566   4.2    7.5   7
# 1323574   1.4    6.5   43
# 1323577   16.5   19.5  17
# 1323580   1.6    13.2  53
# 1323584   7.2    7.3   0
# 1323593   5.2    9.2   28
# 1323595   18.3   19.3  14
# 1323602   3.5    8.3   15
# 1323604   3.2    19.2  85
# 1323607   9.3    18.5  45
# 1341268   4.3    4.6   0

# %%
gardner_death_perf=pd.DataFrame(gardner_death.groupby(['match_id'])['runs_off_bat'].sum())

# %%
gardner_death_perf
# Out:
#           runs_off_bat
# match_id
# 1323556   6
# 1323559   20
# 1323577   17
# 1323580   12
# 1323595   14
# 1323604   68
# 1323607   43

# %%
gardner_perf
# Out:
#           entry  exit  runs_off_bat
# match_id
# 1323554   3.7    4.4   2
# 1323556   19.6   19.6  6
# 1323559   9.4    17.6  24
# 1323566   4.2    7.5   7
# 1323574   1.4    6.5   43
# 1323577   16.5   19.5  17
# 1323580   1.6    13.2  53
# 1323584   7.2    7.3   0
# 1323593   5.2    9.2   28
# 1323595   18.3   19.3  14
# 1323602   3.5    8.3   15
# 1323604   3.2    19.2  85
# 1323607   9.3    18.5  45
# 1341268   4.3    4.6   0

# %%
gardner_perf=gardner_perf.merge(pd.DataFrame(gardner.groupby(['match_id'])['ball'].count()),on='match_id')

# %%
gardner_perf
# Out:
#           entry  exit  runs_off_bat  ball
# match_id
# 1323554   3.7    4.4   2             2
# 1323556   19.6   19.6  6             1
# 1323559   9.4    17.6  24            24
# 1323566   4.2    7.5   7             11
# 1323574   1.4    6.5   43            23
# 1323577   16.5   19.5  17            10
# 1323580   1.6    13.2  53            38
# 1323584   7.2    7.3   0             2
# 1323593   5.2    9.2   28            17
# 1323595   18.3   19.3  14            5
# 1323602   3.5    8.3   15            13
# 1323604   3.2    19.2  85            49
# 1323607   9.3    18.5  45            30
# 1341268   4.3    4.6   0             4

# %%
gardner_death_perf=gardner_death_perf.merge(pd.DataFrame(gardner_death.groupby(['match_id'])['ball'].count()),on='match_id')

# %%
gardner_death_perf
# Out:
#           runs_off_bat  ball
# match_id
# 1323556   6             1
# 1323559   20            21
# 1323577   17            10
# 1323580   12            10
# 1323595   14            5
# 1323604   68            27
# 1323607   43            27

# %%
gardner_perf
# Out:
#           entry  exit  runs_off_bat  ball
# match_id
# 1323554   3.7    4.4   2             2
# 1323556   19.6   19.6  6             1
# 1323559   9.4    17.6  24            24
# 1323566   4.2    7.5   7             11
# 1323574   1.4    6.5   43            23
# 1323577   16.5   19.5  17            10
# 1323580   1.6    13.2  53            38
# 1323584   7.2    7.3   0             2
# 1323593   5.2    9.2   28            17
# 1323595   18.3   19.3  14            5
# 1323602   3.5    8.3   15            13
# 1323604   3.2    19.2  85            49
# 1323607   9.3    18.5  45            30
# 1341268   4.3    4.6   0             4

# %%
gardner_perf['strike_rate']=100*(gardner_perf['runs_off_bat']/gardner_perf['ball'])

# %%
gardner_perf
# Out:
#           entry  exit  runs_off_bat  ball  strike_rate
# match_id
# 1323554   3.7    4.4   2             2     100.000000
# 1323556   19.6   19.6  6             1     600.000000
# 1323559   9.4    17.6  24            24    100.000000
# 1323566   4.2    7.5   7             11    63.636364
# 1323574   1.4    6.5   43            23    186.956522
# 1323577   16.5   19.5  17            10    170.000000
# 1323580   1.6    13.2  53            38    139.473684
# 1323584   7.2    7.3   0             2     0.000000
# 1323593   5.2    9.2   28            17    164.705882
# 1323595   18.3   19.3  14            5     280.000000
# 1323602   3.5    8.3   15            13    115.384615
# 1323604   3.2    19.2  85            49    173.469388
# 1323607   9.3    18.5  45            30    150.000000
# 1341268   4.3    4.6   0             4     0.000000

# %%
gardner_death_perf['strike_rate']=(gardner_death_perf['runs_off_bat']/gardner_death_perf['ball'])*100

# %%
gardner_death_perf
# Out:
#           runs_off_bat  ball  strike_rate
# match_id
# 1323556   6             1     600.000000
# 1323559   20            21    95.238095
# 1323577   17            10    170.000000
# 1323580   12            10    120.000000
# 1323595   14            5     280.000000
# 1323604   68            27    251.851852
# 1323607   43            27    159.259259

# %%
sum(gardner_perf['runs_off_bat'])/sum(gardner_perf['ball'])*100
#Gardner's strike rate at WBBL-09
# Out:
# 148.0349344978166

# %%
sum(gardner_death_perf['runs_off_bat'])/sum(gardner_death_perf['ball'])*100
#Gardner's strike rate in the last 10 overs at WBBL-09
# Out:
# 178.21782178217822

# %%
not_gardner=df_latest[df_latest['striker']!='A Gardner']

# %%
not_gardner.head()
# Out:
#        match_id   season  start_date                                   venue  innings  ball   batting_team   bowling_team     striker non_striker     bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 73582  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  1        0.1   Brisbane Heat  Sydney Sixers  GM Harris   G Redmayne  L Cheatle  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 73583  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  1        0.2   Brisbane Heat  Sydney Sixers  GM Harris   G Redmayne  L Cheatle  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# ...

# %%
sum(not_gardner['runs_off_bat'])/len(not_gardner)*100
# Out:
# 108.01593625498008

# %%
not_gardner_death=df_latest[(df_latest['striker']!='A Gardner') & (df_latest['ball']>10)]

# %%
sum(not_gardner_death['runs_off_bat'])/len(not_gardner_death)*100
# Out:
# 121.79576241750607

# %%
gardner
# Out:
#        match_id   season  start_date                                   venue  innings  ball   batting_team       bowling_team    striker non_striker        bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 73731  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  2        3.7   Sydney Sixers  Brisbane Heat      A Gardner  EA Perry    NM Hancock    2             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 73735  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  2        4.4   Sydney Sixers  Brisbane Heat      A Gardner  EA Perry    JM Kerr       0             0      NaN    NaN      NaN   NaN      NaN       stumped     A Gardner       NaN                NaN
# ...

# %%
gardner_boundaries=len(gardner[gardner['runs_off_bat']==4]) + len(gardner[gardner['runs_off_bat']==6])
gardner_boundaries
# Out:
# 46

# %%
len(gardner[gardner['wides']!=1])
# Out:
# 225

# %%
gardner_boundary_percentage=gardner_boundaries/len(gardner)*100
gardner_boundary_percentage
# Out:
# 20.087336244541483

# %%
top_batters=top_batters.merge(pd.DataFrame(df_latest.groupby(['striker'])['wicket_type'].count()),on='striker')

# %%
top_batters.rename(columns={'wicket_type':'dismissals'},inplace=True)

# %%
top_batters
# Out:
#          striker  runs_off_bat  ball  strike_rate  dismissals
# 0   L Harris      270           136   198.529412   12
# 1   A King        68            40    170.000000   5
# 2   T Flintoff    116           72    161.111111   7
# 3   S Ecclestone  126           81    155.555556   4
# 4   M Brown       105           69    152.173913   5
# ..      ...       ...           ..           ...  ..
# 59  AC Jayangani  133           156   85.256410    8
# 60  R Trenaman    131           156   83.974359    12
# 61  KJ Garth      115           141   81.560284    8
# 62  M Carmichael  69            90    76.666667    5
# 63  T Wilson      85            115   73.913043    4
#
# [64 rows x 5 columns]

# %%
top_batters['average']=top_batters['runs_off_bat']/top_batters['dismissals']

# %%
pd.DataFrame(df.groupby(['striker'])['wicket_type'].count())
# Out:
#                  wicket_type
# striker
# A Bosch          8
# A Capsey         11
# A Day            1
# A Gardner        77
# A Genford        5
# ...              ..
# TMM Newton       4
# TT Beaumont      57
# U Raymond-Hoey   1
# V Krishnamurthy  4
# V Pyke           18
#
# [217 rows x 1 columns]

# %%
batters=[]
for i in range(len(top_batters)):
    batters.append(top_batters['striker'][i])

# %%
for j in range(len(batters)):
    batters[j]=batters[j].replace(' ','_')

# %%
for i in range(len(top_batters)):
    batters[i]=df_latest[df_latest['striker']==top_batters['striker'][i]]

# %%
for i in range(len(batters)):
    batters[i]

# %%
bpb=[]
for i in range(len(top_batters)):
    bpb.append ((len (batters[i][batters[i]['runs_off_bat']==4]) + len (batters[i][batters[i]['runs_off_bat']==6]))/ (len(batters[i])))

# %%
bpb=pd.DataFrame(bpb)
top_batters['bpb']=bpb

# %%
top_batters.sort_values(by='bpb',ascending=False).head(10)
# Out:
#          striker  runs_off_bat  ball  strike_rate  dismissals    average       bpb
# 0   L Harris      270           136   198.529412   12          22.500000  0.375000
# 1   A King        68            40    170.000000   5           13.600000  0.225000
# 6   EA Burns      295           206   143.203883   10          29.500000  0.208738
# 2   T Flintoff    116           72    161.111111   7           16.571429  0.208333
# 7   M Kapp        229           165   138.787879   8           28.625000  0.206061
# 4   M Brown       105           69    152.173913   5           21.000000  0.202899
# 5   A Gardner     339           229   148.034934   12          28.250000  0.200873
# 3   S Ecclestone  126           81    155.555556   4           31.500000  0.197531
# 23  TT Beaumont   194           172   112.790698   11          17.636364  0.180233
# 10  DN Wyatt      263           211   124.644550   14          18.785714  0.180095

# %%
top_batters['bpb']=100*top_batters['bpb']

# %%
top_batters['bpb']=100/top_batters['bpb']

# %%
top_batters.sort_values(by='bpb',inplace=True)

# %%
top_batters.head(10)
# Out:
#          striker  runs_off_bat  ball  strike_rate  dismissals    average       bpb
# 0   L Harris      270           136   198.529412   12          22.500000  2.666667
# 1   A King        68            40    170.000000   5           13.600000  4.444444
# 6   EA Burns      295           206   143.203883   10          29.500000  4.790698
# 2   T Flintoff    116           72    161.111111   7           16.571429  4.800000
# 7   M Kapp        229           165   138.787879   8           28.625000  4.852941
# 4   M Brown       105           69    152.173913   5           21.000000  4.928571
# 5   A Gardner     339           229   148.034934   12          28.250000  4.978261
# 3   S Ecclestone  126           81    155.555556   4           31.500000  5.062500
# 23  TT Beaumont   194           172   112.790698   11          17.636364  5.548387
# 10  DN Wyatt      263           211   124.644550   14          18.785714  5.552632

# %%
plt.figure(figsize=(10,7))
plt.title('Ash Gardner,the perfect balance between runs and hard hitting',fontsize=17)
plt.axvline(6,ls='dashed',color='blue')
plt.axvline(12,ls='dashed',color='blue')
plt.axhline(300,ls='dashed')
plt.xlabel('Balls Per Boundary',fontsize=20)
plt.ylabel('Total Runs',fontsize=20)
plt.scatter(top_batters['bpb'],top_batters['runs_off_bat'],color='#ff007f')
plt.style.use('fivethirtyeight')
for i in range(len(top_batters)):
    if top_batters['striker'][i]=='A Gardner':
        plt.text(top_batters['bpb'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i],color='red')
    if (top_batters['striker'][i]=='L Harris') | (top_batters['striker'][i]=='S Ecclestone')| (top_batters['striker'][i]=='M Brown'):
        plt.text(top_batters['bpb'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])
    if (top_batters['striker'][i]=='EA Burns') | (top_batters['striker'][i]=='M Kapp')| (top_batters['striker'][i]=='JL Jonassen'):
        plt.text(top_batters['bpb'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])
    if (top_batters['striker'][i]=='EA Perry') | (top_batters['striker'][i]=='BL Mooney')| (top_batters['striker'][i]=='AJ Healy'):
        plt.text(top_batters['bpb'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])
    if (top_batters['striker'][i]=='DJS Dottin') | (top_batters['striker'][i]=='L Lee')| (top_batters['striker'][i]=='TM McGrath'):
        plt.text(top_batters['bpb'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])
    if (top_batters['striker'][i]=='HK Matthews') | (top_batters['striker'][i]=='L Wolvaardt')| (top_batters['striker'][i]=='SFM Devine'):
        plt.text(top_batters['bpb'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])
plt.savefig('ash_gardner_1.png')                        
plt.show()

# %%
#1. Ash Gardner and Alyssa Healy (both Sydney Sixers) are the only batters in the region of runs > 300 and balls/boundary<6
#2. Healy opens the batting and gets 4 overs of only 2 fielders outside the 30 yard ring
#3. All the top scorers [Mooney,Perry,Dottin,Wolvaardt] don't quite have Gardner's frequency of getting boundaries
#4. Laura Harris, M Kapp, M Brown,etc. feature in the region of runs<300 but ball/boundary <6 
#5. Therefore in terms of aggregating runs and abilty to clear the ropes, Ash Gardner is no macth to anyone.

# %%
top_batters.sort_values(by='strike_rate',ascending=False,inplace=True)

# %%
top_batters.head()
# Out:
#         striker  runs_off_bat  ball  strike_rate  dismissals    average       bpb
# 0  L Harris      270           136   198.529412   12          22.500000  2.666667
# 1  A King        68            40    170.000000   5           13.600000  4.444444
# 2  T Flintoff    116           72    161.111111   7           16.571429  4.800000
# 3  S Ecclestone  126           81    155.555556   4           31.500000  5.062500
# 4  M Brown       105           69    152.173913   5           21.000000  4.928571

# %%
top_batters.sort_values(by='strike_rate',ascending=False,inplace=True)
top_batters.head(7)
top_batters['BASRA']=top_batters['strike_rate']+top_batters['average']

# %%
plt.figure(figsize=(10,7))
plt.title('Ash Gardner and her explosive strike rate',fontsize=20)
plt.ylabel('Total Runs',fontsize=20)
plt.xlabel('Strike Rate',fontsize=20)
plt.axvline(100,ls='dashed',color='purple')
plt.axvline(140,ls='dashed',color='yellow')
plt.axhline(150,ls='dashed',color='green')
plt.axhline(250,ls='dashed',color='orange')
plt.scatter(top_batters['strike_rate'],top_batters['runs_off_bat'],color='red')
plt.style.use('fivethirtyeight')
for i in range(len(top_batters)):
    if top_batters['striker'][i]=='A Gardner':
        plt.text(top_batters['strike_rate'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i],color='blue')
    if (top_batters['striker'][i]=='L Harris') | (top_batters['striker'][i]=='T Flintoff' )| (top_batters['striker'][i]=='S Ecclestone'):
        plt.text(top_batters['strike_rate'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])
    if (top_batters['striker'][i]=='AJ Healy') | (top_batters['striker'][i]=='BL Mooney' )| (top_batters['striker'][i]=='AC Jayangani'):
        plt.text(top_batters['strike_rate'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])  
    if (top_batters['striker'][i]=='EA Burns') | (top_batters['striker'][i]=='M Kapp' )| (top_batters['striker'][i]=='DJS Dottin'):
        plt.text(top_batters['strike_rate'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])  
    if (top_batters['striker'][i]=='M du Preez') | (top_batters['striker'][i]=='EA Perry' )| (top_batters['striker'][i]=='DN Wyatt'):
        plt.text(top_batters['strike_rate'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])   
    if (top_batters['striker'][i]=='CL Tryon') | (top_batters['striker'][i]=='AE Jones' )| (top_batters['striker'][i]=='TM McGrath'):
        plt.text(top_batters['strike_rate'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])    
plt.savefig('ash_gardner_2.png')        
plt.show()

# %%
#1. In the top right corner, only Burns , Gardner (both Sixers) and Laura Harris feature (SR>130 and Runs>250)
#2. Harris like Healy gets to bat in the 4 over powerplay at the beginning of the innings and is used by Brisbane Heat as a 
#pinch hitter , her average of just 22.50 clealry shows that
#3. another trend that continues is Mooney, Perry, Dottin, du Preez, Wolvaardt made a lot of runs but did not have the SR.
#4. Gardner's ability to bat in the middle overs when 4 fielders are allowed outside the 30 yard ring and still managing
#a hefty strike rate is a big reason why Sydney Sixers have been a very successful team over the years.

# %%
plt.figure(figsize=(10,7))
plt.title('Averages at WBBL 08',fontsize=20)
plt.ylabel('Total Runs',fontsize=20)
plt.xlabel('BASRA',fontsize=20)
plt.axvline(170,ls='dashed',color='brown')
plt.axvline(130,ls='dashed',color='blue')
plt.axhline(150,ls='dashed',color='red')
plt.axhline(300,ls='dashed',color='orange')
plt.scatter(top_batters['BASRA'],top_batters['runs_off_bat'],color='green')
plt.style.use('fivethirtyeight')
for i in range(len(top_batters)):
    if top_batters['striker'][i]=='A Gardner':
        plt.text(top_batters['BASRA'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i],color='blue')
    if (top_batters['striker'][i]=='L Harris') | (top_batters['striker'][i]=='T Flintoff' )| (top_batters['striker'][i]=='S Ecclestone'):
        plt.text(top_batters['BASRA'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])
    if (top_batters['striker'][i]=='AJ Healy') | (top_batters['striker'][i]=='BL Mooney' )| (top_batters['striker'][i]=='AC Jayangani'):
        plt.text(top_batters['BASRA'][i]-2,top_batters['runs_off_bat'][i],top_batters['striker'][i])  
    if (top_batters['striker'][i]=='EA Burns') | (top_batters['striker'][i]=='M Kapp' )| (top_batters['striker'][i]=='DJS Dottin'):
        plt.text(top_batters['BASRA'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])  
    if (top_batters['striker'][i]=='M du Preez') | (top_batters['striker'][i]=='EA Perry' )| (top_batters['striker'][i]=='DN Wyatt'):
        plt.text(top_batters['BASRA'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])   
    if (top_batters['striker'][i]=='CL Tryon') | (top_batters['striker'][i]=='AE Jones' )| (top_batters['striker'][i]=='TM McGrath'):
        plt.text(top_batters['BASRA'][i],top_batters['runs_off_bat'][i],top_batters['striker'][i])    
plt.savefig('ash_gardner_3.png')
plt.show()

# %%
#1. BASRA is a metric that takes into account average and strike rate
#2. Gardner is way ahead of her peers here. Throughout the WBBL 08, she was the only player to have a BASRA over 170 and 
#score more than 300 runs.
#3. Erin Burns, Laura Harris, Tess Flintoff, Sophie Ecclestone, Alana King all have good BASRA's but not the runs
#4. The above 3 graphs are enough to prove Gardner's batting worth at WBBL 08, she was clearly the best batters by whichever way you see it.

# %%
top_batters.sort_values(by='BASRA',ascending=False).head()
# Out:
#         striker  runs_off_bat  ball  strike_rate  dismissals    average       bpb       BASRA
# 0  L Harris      270           136   198.529412   12          22.500000  2.666667  221.029412
# 3  S Ecclestone  126           81    155.555556   4           31.500000  5.062500  187.055556
# 1  A King        68            40    170.000000   5           13.600000  4.444444  183.600000
# 8  JL Jonassen   148           114   129.824561   3           49.333333  6.333333  179.157895
# 2  T Flintoff    116           72    161.111111   7           16.571429  4.800000  177.682540

# %%
df_latest
# Out:
#        match_id   season  start_date                                   venue  innings  ball   batting_team       bowling_team     striker non_striker        bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 73582  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  1        0.1   Brisbane Heat  Sydney Sixers      GM Harris   G Redmayne  L Cheatle     0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# 73583  1323554   2022/23  13-10-2022  Ray Mitchell Oval, Harrup Park, Mackay  1        0.2   Brisbane Heat  Sydney Sixers      GM Harris   G Redmayne  L Cheatle     0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# ...

# %%
top_bowlers=df_latest.groupby(['bowler'])['wicket_type'].count().sort_values(ascending=False)
top_bowlers=pd.DataFrame(top_bowlers)

# %%
top_bowlers=top_bowlers[top_bowlers['wicket_type']>=1]

# %%
top_bowlers=top_bowlers.merge(pd.DataFrame(df_latest.groupby(['bowler'])['runs_off_bat'].sum()+ df_latest.groupby(['bowler'])['extras'].sum()),on='bowler' )

# %%
top_bowlers.rename(columns={'ball':'balls','wicket_type':'wickets',0:'runs_given','ball':'balls'},inplace=True)

# %%
top_bowlers=top_bowlers.merge(pd.DataFrame(df_latest.groupby(['bowler'])['ball'].count()),on='bowler')

# %%
top_bowlers.reset_index(inplace=True)

# %%
top_bowlers.rename(columns={'ball':'balls','wicket_type':'wickets',0:'runs_given','ball':'balls'},inplace=True)

# %%
top_bowlers['economy']=6*top_bowlers['runs_given']/top_bowlers['balls']
top_bowlers['strike_rate']=top_bowlers['balls']/top_bowlers['wickets']
top_bowlers['average']=top_bowlers['runs_given']/top_bowlers['wickets']

# %%
bowlers=[]
for i in range(len(top_bowlers)):
    bowlers.append(top_bowlers['bowler'][i])

# %%
for j in range(len(bowlers)):
    bowlers[j]=bowlers[j].replace(' ','_')

# %%
for i in range(len(top_bowlers)):
    bowlers[i]=df_latest[df_latest['bowler']==top_bowlers['bowler'][i]]

# %%
dots=[]
for i in range(len(top_bowlers)):
    dots.append (len (bowlers[i][bowlers[i]['runs_off_bat']==0]))

# %%
dots=pd.DataFrame(dots)

# %%
top_bowlers['dots']=dots

# %%
top_bowlers['dots_frequency']=top_bowlers['balls']/top_bowlers['dots']

# %%
top_bowlers
# Out:
#            bowler  wickets  runs_given  balls    economy  strike_rate    average  dots  dots_frequency
# 0   ML Schutt      30       357         336    6.375000   11.200000    11.900000  157   2.140127
# 1   JL Jonassen    28       391         340    6.900000   12.142857    13.964286  112   3.035714
# 2   AC Kerr        26       418         359    6.986072   13.807692    16.076923  133   2.699248
# 3   NM Hancock     25       417         314    7.968153   12.560000    16.680000  149   2.107383
# 4   A Gardner      23       380         343    6.647230   14.913043    16.521739  135   2.540741
# 5   A Wellington   23       378         331    6.851964   14.391304    16.434783  132   2.507576
# 6   SK Moloney     22       306         293    6.266212   13.318182    13.909091  124   2.362903
# 7   A Sutherland   22       393         299    7.886288   13.590909    17.863636  115   2.600000
# 8   S Ecclestone   21       378         346    6.554913   16.476190    18.000000  166   2.084337
# ...

# %%
top_bowlers.sort_values(by='economy',inplace=False)
# Out:
#            bowler  wickets  runs_given  balls    economy  strike_rate    average  dots  dots_frequency
# 54  AC Mushangwe   2        21          24     5.250000   12.000000    10.500000  14    1.714286
# 17  M Kapp         14       276         289    5.730104   20.642857    19.714286  148   1.952703
# 41  A Smith        6        135         141    5.744681   23.500000    22.500000  48    2.937500
# 9   JL Barsby      19       297         310    5.748387   16.315789    15.631579  124   2.500000
# 13  A King         17       278         287    5.811847   16.882353    16.352941  140   2.050000
# 10  M Strano       19       291         293    5.959044   15.421053    15.315789  129   2.271318
# 43  E Hayward      6        202         203    5.970443   33.833333    33.666667  86    2.360465
# 46  CL Tryon       5        95          95     6.000000   19.000000    19.000000  40    2.375000
# 38  JM Kerr        7        187         181    6.198895   25.857143    26.714286  75    2.413333
# ...

# %%
count=0
for i in range(len(top_bowlers)):
    count+=1
    if (top_bowlers['bowler'][i]=='A Gardner'):
        print(count)
# Out:
# 5

# %%
top_bowlers=top_bowlers[top_bowlers['balls']>=50]

# %%
top_bowlers
# Out:
#            bowler  wickets  runs_given  balls   economy  strike_rate    average  dots  dots_frequency
# 0   ML Schutt      30       357         336    6.375000  11.200000    11.900000  157   2.140127
# 1   JL Jonassen    28       391         340    6.900000  12.142857    13.964286  112   3.035714
# 2   AC Kerr        26       418         359    6.986072  13.807692    16.076923  133   2.699248
# 3   NM Hancock     25       417         314    7.968153  12.560000    16.680000  149   2.107383
# 4   A Gardner      23       380         343    6.647230  14.913043    16.521739  135   2.540741
# 5   A Wellington   23       378         331    6.851964  14.391304    16.434783  132   2.507576
# 6   SK Moloney     22       306         293    6.266212  13.318182    13.909091  124   2.362903
# 7   A Sutherland   22       393         299    7.886288  13.590909    17.863636  115   2.600000
# 8   S Ecclestone   21       378         346    6.554913  16.476190    18.000000  166   2.084337
# ...

# %%
gardner_bowl=df_latest[df_latest['bowler']=='A Gardner']

# %%
gardner_bowling=pd.DataFrame(gardner_bowl.groupby(['match_id'])['runs_off_bat'].sum())

# %%
gardner_bowling=gardner_bowling.merge(pd.DataFrame(gardner_bowl.groupby(['match_id'])['ball'].min()),on='match_id')

# %%
gardner_bowling=gardner_bowling.merge(pd.DataFrame(gardner_bowl.groupby(['match_id'])['ball'].max()),on='match_id')

# %%
gardner_bowling.rename(columns={'ball_y':'entry','ball':'balls','runs_off_bat':'runs_given',0:'team_economy','wicket_type':'wickets'},inplace=True)

# %%
gardner_bowling
# Out:
#           runs_given  ball_x  entry
# match_id
# 1323554   28          7.1     16.6
# 1323556   26          5.1     17.6
# 1323559   19          5.1     17.6
# 1323566   20          6.1     17.6
# 1323574   23          4.1     10.6
# 1323577   21          1.1     17.6
# 1323580   22          0.1     16.6
# 1323584   19          3.1     13.6
# 1323590   21          0.1     10.6
# 1323593   27          4.1     17.6
# 1323595   30          5.1     17.6
# 1323602   31          4.1     16.6
# 1323604   28          1.1     17.6
# 1323607   32          5.1     17.6
# 1341268   30          3.1     17.7

# %%
gardner_bowling=gardner_bowling.merge(pd.DataFrame(gardner_bowl.groupby(['match_id'])['ball'].count()),on='match_id')

# %%
gardner_bowling['economy']=6*gardner_bowling['runs_given']/gardner_bowling['ball']

# %%
gardner_bowling=gardner_bowling.merge(pd.DataFrame(gardner_bowl.groupby(['match_id'])['wicket_type'].count()),on='match_id')

# %%
gardner_bowling
# Out:
#           runs_given  ball_x  entry  ball   economy  wicket_type
# match_id
# 1323554   28          7.1     16.6   24    7.000000  0
# 1323556   26          5.1     17.6   24    6.500000  1
# 1323559   19          5.1     17.6   24    4.750000  2
# 1323566   20          6.1     17.6   24    5.000000  1
# 1323574   23          4.1     10.6   18    7.666667  4
# 1323577   21          1.1     17.6   24    5.250000  1
# 1323580   22          0.1     16.6   24    5.500000  3
# 1323584   19          3.1     13.6   24    4.750000  1
# 1323590   21          0.1     10.6   18    7.000000  1
# 1323593   27          4.1     17.6   24    6.750000  4
# 1323595   30          5.1     17.6   24    7.500000  2
# 1323602   31          4.1     16.6   24    7.750000  1
# 1323604   28          1.1     17.6   24    7.000000  1
# 1323607   32          5.1     17.6   24    8.000000  1
# 1341268   30          3.1     17.7   19    9.473684  0

# %%
Sixers_bowling=df_latest[df_latest['bowling_team']=='Sydney Sixers']

# %%
sixers_econ=6*sum(Sixers_bowling['runs_off_bat'])/len(Sixers_bowling)
sixers_econ
#Sydney Sixers economy
# Out:
# 6.738780207134638

# %%
gardner_bowling=gardner_bowling.merge(pd.DataFrame(6*Sixers_bowling.groupby(['match_id'])['runs_off_bat'].sum()/Sixers_bowling.groupby(['match_id'])['ball'].count()),on='match_id')

# %%
gardner_bowling
# Out:
#           runs_given  ball_x  entry  ball   economy  wicket_type         0
# match_id
# 1323554   28          7.1     16.6   24    7.000000  0            6.435484
# 1323556   26          5.1     17.6   24    6.500000  1            6.292683
# 1323559   19          5.1     17.6   24    4.750000  2            5.754098
# 1323566   20          6.1     17.6   24    5.000000  1            6.677419
# 1323574   23          4.1     10.6   18    7.666667  4            7.297297
# 1323577   21          1.1     17.6   24    5.250000  1            6.138462
# 1323580   22          0.1     16.6   24    5.500000  3            7.289256
# 1323584   19          3.1     13.6   24    4.750000  1            7.826087
# 1323590   21          0.1     10.6   18    7.000000  1            5.294118
# 1323593   27          4.1     17.6   24    6.750000  4            5.394958
# 1323595   30          5.1     17.6   24    7.500000  2            8.380165
# ...

# %%
top_bowlers.head()
# Out:
#         bowler  wickets  runs_given  balls   economy  strike_rate    average  dots  dots_frequency
# 0  ML Schutt    30       357         336    6.375000  11.200000    11.900000  157   2.140127
# 1  JL Jonassen  28       391         340    6.900000  12.142857    13.964286  112   3.035714
# 2  AC Kerr      26       418         359    6.986072  13.807692    16.076923  133   2.699248
# 3  NM Hancock   25       417         314    7.968153  12.560000    16.680000  149   2.107383
# 4  A Gardner    23       380         343    6.647230  14.913043    16.521739  135   2.540741

# %%
top_batters.to_csv('top_batters.csv')

# %%
top_bowlers.to_csv('top_bowlers.csv')

# %%
gardner_perf.to_csv('gardner_perf.csv')
gardner_bowling.to_csv('gardner_bowling.csv')
gardner_death_perf.to_csv('gardner_death_perf.csv')

# %%
average_sr
# Out:
# 108.73307770561075

# %%
top_bowlers
# Out:
#            bowler  wickets  runs_given  balls   economy  strike_rate    average  dots  dots_frequency
# 0   ML Schutt      30       357         336    6.375000  11.200000    11.900000  157   2.140127
# 1   JL Jonassen    28       391         340    6.900000  12.142857    13.964286  112   3.035714
# 2   AC Kerr        26       418         359    6.986072  13.807692    16.076923  133   2.699248
# 3   NM Hancock     25       417         314    7.968153  12.560000    16.680000  149   2.107383
# 4   A Gardner      23       380         343    6.647230  14.913043    16.521739  135   2.540741
# 5   A Wellington   23       378         331    6.851964  14.391304    16.434783  132   2.507576
# 6   SK Moloney     22       306         293    6.266212  13.318182    13.909091  124   2.362903
# 7   A Sutherland   22       393         299    7.886288  13.590909    17.863636  115   2.600000
# 8   S Ecclestone   21       378         346    6.554913  16.476190    18.000000  166   2.084337
# ...

# %%
plt.figure(figsize=(10,7))
plt.title('Wickets vs Economy at WBBL 08',fontsize=20)
plt.ylabel('Economy',fontsize=20)
plt.xlabel('Total Wickets',fontsize=20)
plt.axhline(6.5,ls='dashed',color='yellow')
plt.axhline(7.5,ls='dashed',color='red')
plt.axvline(20,ls='dashed',color='gold')
plt.axvline(10,ls='dashed',color='green')
plt.scatter(top_bowlers['wickets'],top_bowlers['economy'],color='purple')
for i in range(54):
    if (top_bowlers['bowler'][i]=='A Gardner'):
        plt.text(top_bowlers['wickets'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i],color='red')
    if (top_bowlers['bowler'][i]=='ML Schutt')|(top_bowlers['bowler'][i]=='JL Jonassen')|(top_bowlers['bowler'][i]=='AC Kerr'):
        plt.text(top_bowlers['wickets'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])    
    if (top_bowlers['bowler'][i]=='NM Hancock')|(top_bowlers['bowler'][i]=='A Wellington')|(top_bowlers['bowler'][i]=='A Sutherland'):
        plt.text(top_bowlers['wickets'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])
    if (top_bowlers['bowler'][i]=='M Kapp')|(top_bowlers['bowler'][i]=='A Smith')|(top_bowlers['bowler'][i]=='A King'):
        plt.text(top_bowlers['wickets'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])    
    if (top_bowlers['bowler'][i]=='M Strano')|(top_bowlers['bowler'][i]=='CL Tryon')|(top_bowlers['bowler'][i]=='SK Moloney'):
        plt.text(top_bowlers['wickets'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])    
    if (top_bowlers['bowler'][i]=='EA Perry')|(top_bowlers['bowler'][i]=='HJ Darlington')|(top_bowlers['bowler'][i]=='NJ Carey'):
        plt.text(top_bowlers['wickets'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])  
    if (top_bowlers['bowler'][i]=='S Molineux')|(top_bowlers['bowler'][i]=='S Ismail')|(top_bowlers['bowler'][i]=='M Brown'):
        plt.text(top_bowlers['wickets'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])        
plt.savefig('ash_gardner_4.png')        
plt.show()

# %%
#1. only 2 bowlers feature in the region of wickets>20 and economy<6.5- Schutt & Moloney
#2. Gardner features in the region of economy between 6.5 to 7.5 and wickets>20
#3. Gardner bowled most of her overs after the powerplay and often bowled 1 over in the power surge
#4. for an off spinner who regularly completes her 4 overs (12/15 matches) it is an achievement to have an economy of 6.65
#especially when her team's economy is 6.74

# %%
top_bowlers.sort_values(by='dots_frequency',ascending=True)
# Out:
#            bowler  wickets  runs_given  balls   economy  strike_rate    average  dots  dots_frequency
# 14  D Brown        17       382         361    6.349030  21.235294    22.470588  190   1.900000
# 17  M Kapp         14       276         289    5.730104  20.642857    19.714286  148   1.952703
# 57  HL Ferling     1        62          57     6.526316  57.000000    62.000000  29    1.965517
# 18  KJ Garth       14       323         301    6.438538  21.500000    23.071429  153   1.967320
# 50  T Flintoff     4        236         194    7.298969  48.500000    59.000000  95    2.042105
# 13  A King         17       278         287    5.811847  16.882353    16.352941  140   2.050000
# 35  HNK Jensen     8        281         235    7.174468  29.375000    35.125000  113   2.079646
# 8   S Ecclestone   21       378         346    6.554913  16.476190    18.000000  166   2.084337
# 3   NM Hancock     25       417         314    7.968153  12.560000    16.680000  149   2.107383
# ...

# %%
plt.figure(figsize=(10,7))
plt.title('Wickets vs Average at WBBL 08',fontsize=20)
plt.ylabel('Total Wickets',fontsize=20)
plt.xlabel('Average',fontsize=20)
plt.axhline(20,ls='dashed',color='yellow')
plt.axhline(10,ls='dashed',color='green')
plt.axvline(30,ls='dashed',color='pink')
plt.axvline(20,ls='dashed',color='orange')
plt.scatter(top_bowlers['average'],top_bowlers['wickets'])
for i in range(54):
    if  (top_bowlers['bowler'][i]=='A Gardner'):
        plt.text(top_bowlers['average'][i],top_bowlers['wickets'][i],top_bowlers['bowler'][i],color='red')
    if (top_bowlers['bowler'][i]=='ML Schutt')|(top_bowlers['bowler'][i]=='JL Jonassen')|(top_bowlers['bowler'][i]=='AC Kerr'):
        plt.text(top_bowlers['average'][i],top_bowlers['wickets'][i],top_bowlers['bowler'][i])    
    if (top_bowlers['bowler'][i]=='NM Hancock'):
        plt.text(top_bowlers['average'][i],top_bowlers['wickets'][i],top_bowlers['bowler'][i])
    if (top_bowlers['bowler'][i]=='M Kapp')|(top_bowlers['bowler'][i]=='A Smith')|(top_bowlers['bowler'][i]=='A King'):
        plt.text(top_bowlers['average'][i],top_bowlers['wickets'][i],top_bowlers['bowler'][i])    
    if (top_bowlers['bowler'][i]=='M Strano')|(top_bowlers['bowler'][i]=='CL Tryon')|(top_bowlers['bowler'][i]=='SK Moloney'):
        plt.text(top_bowlers['average'][i],top_bowlers['wickets'][i],top_bowlers['bowler'][i])    
    if (top_bowlers['bowler'][i]=='EA Perry')|(top_bowlers['bowler'][i]=='HJ Darlington')|(top_bowlers['bowler'][i]=='NJ Carey'):
        plt.text(top_bowlers['average'][i],top_bowlers['wickets'][i],top_bowlers['bowler'][i])  
    if (top_bowlers['bowler'][i]=='S Molineux')|(top_bowlers['bowler'][i]=='S Ismail')|(top_bowlers['bowler'][i]=='M Brown'):
        plt.text(top_bowlers['average'][i],top_bowlers['wickets'][i],top_bowlers['bowler'][i])   
plt.savefig('ash_gardner_5.png')        
plt.show()

# %%
#1. Ash Gardner features in the best region: Wickets>20, average<20
#2. This is the region all the top bowlers of the season feature
#3. an average under 20 suggests almost 2 wickets every spell

# %%
plt.figure(figsize=(10,7))
plt.title('Economy vs Dot Balls at WBBL 08',fontsize=20)
plt.ylabel('Economy',fontsize=20)
plt.xlabel('Dot Ball Frequency',fontsize=20)
plt.axhline(6.5,ls='dashed',color='yellow')
plt.axhline(7.5,ls='dashed',color='green')
plt.axvline(2.5,ls='dashed',color='pink')
plt.axvline(3,ls='dashed',color='orange')
plt.scatter(top_bowlers['dots_frequency'],top_bowlers['economy'],color='orange')
for i in range(54):
    if  (top_bowlers['bowler'][i]=='A Gardner'):
        plt.text(top_bowlers['dots_frequency'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i],color='blue')
    if (top_bowlers['bowler'][i]=='ML Schutt')|(top_bowlers['bowler'][i]=='JL Jonassen')|(top_bowlers['bowler'][i]=='AC Kerr'):
        plt.text(top_bowlers['dots_frequency'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])    
    if (top_bowlers['bowler'][i]=='NM Hancock')|(top_bowlers['bowler'][i]=='D Brown'):
        plt.text(top_bowlers['dots_frequency'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])
    if (top_bowlers['bowler'][i]=='M Kapp')|(top_bowlers['bowler'][i]=='A Smith')|(top_bowlers['bowler'][i]=='A King'):
        plt.text(top_bowlers['dots_frequency'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])    
    if (top_bowlers['bowler'][i]=='M Strano')|(top_bowlers['bowler'][i]=='CL Tryon')|(top_bowlers['bowler'][i]=='SK Moloney'):
        plt.text(top_bowlers['dots_frequency'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])    
    if (top_bowlers['bowler'][i]=='EA Perry')|(top_bowlers['bowler'][i]=='HJ Darlington')|(top_bowlers['bowler'][i]=='NJ Carey'):
        plt.text(top_bowlers['dots_frequency'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])  
    if (top_bowlers['bowler'][i]=='S Molineux')|(top_bowlers['bowler'][i]=='S Ismail')|(top_bowlers['bowler'][i]=='M Brown'):
        plt.text(top_bowlers['dots_frequency'][i],top_bowlers['economy'][i],top_bowlers['bowler'][i])       
plt.savefig('ash_gardner_6.png')
plt.show()

# %%
#1. The best region is the bottom left one 
#2. Ash Gardner falls just short of the elite economy of 6.5 and elite dot frequency of 2.50
#3. This shows that while maintaining a great economy, Gardner does not have a great dot frequency
#4. this shows her continuous plan of bowling loopy flighted deliveries according to her field.
